# %% [markdown]
# Now that we have the unlabeled data, we need to label it. We cannot do this manually as it would take a lot of time for 9000 instances. Instead, we can pass them to a LLM like gpt 3.5 and ask for the labels. We are assuming that the answers that it gives is always perfect. While this is not actually true, but it is probably giving the best answers anyways (because it is already  very good at language tasks).

# %% [markdown]
# Before sending them, we should make sure they are properly readable by LLM.

# %%
import pandas as pd
import unicodedata

def clean_text(text):
    if isinstance(text, str):
        # Normalize Unicode characters
        text = unicodedata.normalize('NFKD', text).encode('ASCII', 'ignore').decode('ASCII')
        
        # Remove non-printable characters
        text = ''.join(char for char in text if char.isprintable())
        
    return text

input_file_path = 'articles_filtered.csv'
output_file_path = 'art.csv'

df = pd.read_csv(input_file_path, on_bad_lines='skip')

for column in df.columns:
    if df[column].dtype == 'object':
        df[column] = df[column].apply(clean_text)


df.to_csv(output_file_path, index=False, quoting=1)  

print(f"Cleaned data saved to {output_file_path}")
print(f"Number of rows in the cleaned file: {len(df)}")
# Out:
# Cleaned data saved to art.csv
# Number of rows in the cleaned file: 6488

# %% [markdown]
# also, we should remove content that is too large to pass to LLM once, because of its content size.

# %%
df = pd.read_csv('art.csv')

max_content_length = 5000
df['content_length'] = df['content'].str.len()

df_filtered = df[df['content_length'] <= max_content_length]

df_filtered = df_filtered.drop(columns=['content_length'])

# Save the filtered DataFrame back to a CSV file
df_filtered.to_csv('filtered_art.csv', index=False)

# %%
# !pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.35.13-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from openai) (4.4.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from openai) (2.7.4)
# Requirement already satisfied: sniffio in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from openai) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\umutc\appdata\roaming\python\python310\site-packages (from anyio<5,>=3.5.0->openai) (1.1.3)
# Requirement already satisfied: certifi in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.18.4)
# Requirement already satisfied: colorama in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading openai-1.35.13-py3-none-any.whl (328 kB)
#    ---------------------------------------- 0.0/328.5 kB ? eta -:--:--
#    ------------- -------------------------- 112.6/328.5 kB 3.3 MB/s eta 0:00:01
#    --------------------------- ------------ 225.3/328.5 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 328.5/328.5 kB 2.9 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Installing collected packages: distro, openai
# Successfully installed distro-1.9.0 openai-1.35.13

# %% [markdown]
# Calling one by one takes too much time (one call returns after 10 seconds, we have 6000 instances, which will take more than one day). Thus we need to make multiple calls ones. Checking if our function works:

# %%
import asyncio
import aiohttp
import ssl
import certifi
import nest_asyncio

nest_asyncio.apply()

MODEL = "gpt-3.5-turbo"
OPENAI_SECRET_KEY = "mykey"  

async def call_chatgpt_async(session, prompt: str):
    payload = {
        'model': MODEL,
        'messages': [
            {"role": "user", "content": prompt}
        ]
    }
    try:
        async with session.post(
            url='https://api.openai.com/v1/chat/completions',
            headers={"Content-Type": "application/json", "Authorization": f"Bearer {OPENAI_SECRET_KEY}"},
            json=payload,
            ssl=ssl.create_default_context(cafile=certifi.where())
        ) as response:
            response = await response.json()
        if "error" in response:
            print(f"OpenAI request failed with error {response['error']}")
        return response['choices'][0]['message']['content']
    except:
        print("Request failed.")

async def call_chatgpt_bulk(prompts):
    async with aiohttp.ClientSession() as session:
        tasks = [call_chatgpt_async(session, prompt) for prompt in prompts]
        return await asyncio.gather(*tasks)

if __name__ == "__main__":
    prompts = ["what is 2+2 answer short", "what is 4/2 answer short", "what is 2*3 answer short"]
    results = asyncio.run(call_chatgpt_bulk(prompts))
    print(results)
# Out:
# ['4', '2', '6']

# %% [markdown]
# We see that it is working. Now, I implemented a code for calling the llm making it answer in the format:
# -acquirer
# -acquired
# -price
# than I save the answer to an csv file. I also made a function for creating the training json file in Spacy format as I thought it will be easier to make the model using it.
#
# There is also a mechanism where if the code stops, it saves the files and after rerun, it skips the already proccessed files.

# %%
import csv
import json
import os

nest_asyncio.apply()

MODEL = "gpt-3.5-turbo"
OPENAI_SECRET_KEY = "mykey"  
CSV_FILE = 'filtered_art.csv'  
NUM_INSTANCES = 80

def process_article(title, content):
    return f"{title}\n\n{content}\n\n------YOUR MISSION------\ngive the info of : \n-acquirer \n-acquired \n-price \nwrite not specified if not specified, do not write anything else, I will be using your output to label my data"

def extract_entities(output, full_text):
    lines = output.strip().split('\n')
    entity_dict = {}

    for line in lines:
        if ':' in line:
            entity_type, value = line.split(':', 1)
            entity_type = entity_type.strip().upper()
            entity_type = entity_type.lstrip('-').strip()
            value = value.strip()
            if value.lower() != 'not specified':
                entity_dict[entity_type] = value

    if not entity_dict:
        return

    for entity_type, value in entity_dict.items():
        if value =='':
            break
        start = 0
        while True:
            start = full_text.find(value, start)
            if start == -1:
                break
            end = start + len(value)
            yield (start, end, entity_type)
            start = end

def create_spacy_format(text, entities):
    return (text, {'entities': entities})

def load_json(filename):
    if os.path.exists(filename):
        with open(filename, 'r') as jsonfile:
            return json.load(jsonfile)
    return []

def save_json(filename, data):
    with open(filename, 'w') as jsonfile:
        json.dump(data, jsonfile, indent=2)

def get_prompts_from_csv(csv_file, num_instances, processed_titles):
    prompts = []
    articles = []
    with open(csv_file, 'r', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        rows = list(reader)
        
        for row in rows:
            if len(prompts) >= num_instances:
                break
            
            title = row['title']
            if title not in processed_titles:
                content = row['content']
                prompt = process_article(title, content)
                prompts.append(prompt)
                articles.append((title, content))
    
    return prompts, articles

async def main():
    output_file = 'ner_training_data.json'
    processed_file = 'processed_articles.json'
    csv_output_file = 'processed_articles.csv'

    spacy_data = load_json(output_file)
    processed_articles = load_json(processed_file)

    ner_processed_titles = set(item[0].split('\n')[0] for item in spacy_data)
    all_processed_titles = set(item['title'] for item in processed_articles)

    prompts, articles = get_prompts_from_csv(CSV_FILE, NUM_INSTANCES, all_processed_titles)
    results = await call_chatgpt_bulk(prompts)

    with open(csv_output_file, 'a', newline='') as csvfile:
        fieldnames = ['title', 'content', 'llm_output']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        
        if csvfile.tell() == 0:
            writer.writeheader()

        for (title, content), llm_output in zip(articles, results):
            print(f"Processing article: {title}")

            writer.writerow({
                'title': title,
                'content': content,
                'llm_output': llm_output
            })

            full_text = f"{title}\n\n{content}"
            entities = list(extract_entities(llm_output, full_text))

            if entities and title not in ner_processed_titles:
                spacy_format = create_spacy_format(full_text, entities)
                spacy_data.append(spacy_format)
                ner_processed_titles.add(title)

            processed_articles.append({'title': title, 'has_entities': bool(entities)})
            all_processed_titles.add(title)

        save_json(output_file, spacy_data)
        save_json(processed_file, processed_articles)

    print(f"Data processing complete. NER training data saved to '{output_file}'.")
    print(f"Processed articles with LLM output saved to '{csv_output_file}'.")
    print(f"List of all processed articles saved to '{processed_file}'.")

if __name__ == "__main__":
    asyncio.run(main())
# Out:
# Processing article: 4 Charts Show Startup M&A Deal-Making Is Not Moving In The Direction We Expected
# Processing article: White & Case advises F-Secure on acquisition of mobile consumer security business from Lookout
# Processing article: Mergers & Acquisitions 2023 Deals of the Year: Jacobs Acquired Streetlight from Macquarie and Activate
# Processing article: CVS closes $10.6B acquisition of Oak Street Health to expand primary care footprint
# Processing article: Mergers & Acquisitions 2023 Deals of the Year: Choice Hotels Acquired Radisson Hotel Group Americas
# Processing article: April M&A Roundup: Activity Ticks Up Again After March Dip
# Processing article: Google Acquisition History: What Are the Biggest Companies Google Owns?
# Processing article: WilmerHale Advises Lookout in Acquisition of its Consumer Mobile Security Business Segment
# Processing article: Will Microsoft-Activision Deal Go Through? For Merger Market, It May Not Matter
# Processing article: Why Startups May Soon Be Buying More Startups
# Processing article: Council Post: Post Acquisition Communications: How To Succeed After Day One
# Processing article: Dykema's 2023 M&A Activity Off to a Fast Start
# Processing article: MSP M&A: ePlus Acquires Network Solutions Group From CCI Systems -
# Processing article: Republic sees growing returns from US Ecology acquisition, eyes additional M&A opportunities
# Processing article: Apple Acquisition History: The Biggest Companies Apple Owns
# Processing article: Kaiser Permanente to acquire Geisinger Health in bid to launch multisystem VBC platform
# Processing article: US power M&A deal values grow YOY in Q1 2023
# Processing article: Mergers & Acquisitions 2023 Deals of the Year: AZZ Acquired Sequas Precoat Metals Division
# Processing article: Amazon's Biggest Acquisitions: What Companies Does Amazon Own?
# Processing article: Kaiser Permanente to acquire Geisinger Health and form value-based care network
# Processing article: Penske to acquire Star Truck Rentals in second deal this year
# Processing article: Penske makes second acquisition this year, adds nearly 2,000 trucks
# Processing article: Trimac Transportation acquires small bulk fleet, warehouser
# Processing article: Q1 2023 M&A Transactions Lowest Since 2019
# Processing article: ePlus Acquires Network Solutions Group Assets, Expands National Presence -
# Processing article: Covenant buys Arkansas-based poultry carrier for $100M
# Processing article: Major waste companies spent an estimated $563M on Q1 acquisitions, with more to come this year
# Processing article: SPB Hospitality Completes Merger with Krystal Restaurants
# Processing article: M&A: MSP Corp Announces Private Equity Roll Up of 15 MSPs -
# Processing article: Snell & Wilmer Advises Fintech Startup Greenwood in Acquisition of Kinly
# Processing article: Above Food to go public through SPAC merger
# Processing article: FleetPride Acquires Frame Service Inc.
# Processing article: CIIG Capital Partners II, Inc. Completes Business Combination with Zapp
# Processing article: MAPCO Express Network Sells to Two Buyers
# Processing article: UK Regulator Blocked Microsofts $69 Billion Acquisition of Activision Blizzard
# Processing article: Graybar Acquires Valin Corp. in Diversification Move
# Processing article: CBRE Adds Veteran Investment Banker as Chief Investment Officer
# Processing article: Cogent closes buy of T-Mobiles Wireline Business
# Processing article: DoJ review underway in T-Mobiles proposed acquisition of Mint Mobile
# Processing article: Fluid System Components Acquires Norcan Fluid Power
# Processing article: Columbus McKinnon Acquires Automation Company montratec
# Processing article: Sompo to focus on integration after flurry of acquisitions
# Processing article: LCMC Health legal fight makes local hospital system a national test case
# Processing article: EVisit acquires Bluestream Health to build out digital tools as hospitals double down on telehealth strategies
# Processing article: Honeywell to Acquire Compressor Controls Corp.
# Processing article: Abbott completes $890M acquisition of Cardiovascular Systems
# Processing article: Bipartisan bill revives efforts to expand FTC oversight to nonprofit hospitals
# Processing article: Daikin Applied Acquires Carroll Air Systems
# Processing article: Law firms look to artificial intelligence and M&A for help
# Processing article: White & Case advises Teleperformance on 3 billion voluntary public offer to acquire Majorel
# Processing article: Airbus, Safran and Tikehau Capital finalise acquisition of Aubert & Duval
# Processing article: 15 healthcare mergers and acquisitions making headlines in April
# Processing article: TD's failed acquisition highlights our broken M&A process
# Processing article: House OKs beefed-up state oversight of proposed health care sales, mergers
# Processing article: Healthcare DealmakersKaiser Permanente acquiring Geisinger; Michigan's $7B academic merger
# Processing article: 3 Ways to Unlock M&A Value in a Challenging Credit Environment
# Processing article: Alltech acquires majority interest in Agolin
# Processing article: The MSP M&A Market 2023: Bigger Deals, More Money, More Rollups -
# Processing article: Wake up to the people issues
# Processing article: Monarch E&S swoops for Virginia MGA
# Processing article: NCUA Approves 33 Mergers in the First Quarter of 2023, Trending Downward
# Processing article: Wilson Sonsini Advises Via on Its Acquisition of MPEG LA
# Processing article: DSM, Firmenich complete merger, forming new company
# Processing article: Procure IT Formed Through Merger Of Four Technology Advisors -
# Processing article: Option Care Health to pick up home health and hospice firm Amedisys in $3.6B deal
# Processing article: Bell Acquires FX Innovation to Expand Cloud Managed Services -
# Processing article: Hub swoops for financial institutions specialist
# Processing article: DSM and Firmenich complete merger to become trailblazer in nutrients, flavours, and fragrances
# Processing article: Payoneer hunts for acquisitions
# Processing article: Podcast: Delivering the deal
# Processing article: America needs a jab in its corporate backside
# Processing article: Wisconsin has seen several hospital mergers in the last year. How could they affect patients?
# Processing article: Strategies for Successful Corporate Separations
# Processing article: Cresset Expands AuM With Acquisition, Adds Sports, Entertainment Clout
# Processing article: Lockton buys in Brazil
# Processing article: Amcor Announces Intent to Acquire Moda Systems
# Processing article: Pinnacle Mergers & Acquisitions Represents Don Elliott in the Sale of Don Elliott Autoworld
# Processing article: Download this report to better manage culture risks in M&As.
# Processing article: ARKO Firms Up Growth Strategy With Oak Street Deal Extension
# Processing article: FleetPride Acquires Frame Service Inc. in Indiana
# Data processing complete. NER training data saved to 'ner_training_data.json'.
# Processed articles with LLM output saved to 'processed_articles.csv'.
# List of all processed articles saved to 'processed_articles.json'.

# %% [markdown]
# I experimented with number of instances we pass at one async call to gpt. If I made 100 pass, I got rate limits as you can send 60000 tokens per minute. I found 80 as a sweet spot. If I got an error, the json files were not being updated, thus I wrote the following code to add the processed files at the error session.

# %%
def process_missing_articles():
    ner_data = load_json('ner_training_data.json')
    processed_articles = load_json('processed_articles.json')

    ner_titles = set(item[0].split('\n')[0] for item in ner_data)
    processed_titles = set(item['title'] for item in processed_articles)

    with open('processed_articles.csv', 'r', newline='', encoding='utf-8', errors='ignore') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            title = row['title']
            content = row['content']
            llm_output = row['llm_output']

            # Check if article is missing from both JSON files
            if title not in ner_titles and title not in processed_titles:
                # Add to ner_training_data.json
                full_text = f"{title}\n\n{content}"
                entities = extract_entities(llm_output, full_text)
                if entities:
                    ner_data.append(create_spacy_format(full_text, entities))

                # Add to processed_articles.json
                processed_articles.append({
                    'title': title,
                    'has_entities': bool(entities)
                })

                print(f"Added missing article: {title}")

    save_json('ner_training_data.json', ner_data)
    save_json('processed_articles.json', processed_articles)


if __name__ == "__main__":
    process_missing_articles()
    print("Processing complete. Both JSON files have been updated with missing articles.")
# Out:
# Processing complete. Both JSON files have been updated with missing articles.

# %% [markdown]
# Now, I run these two functions in a loop until I finish all the data, with stopping for 1 minute between each call, for not hitting the rate limits.

# %%
import time
while True:
    asyncio.run(main())
    process_missing_articles()
    print("Processing complete. Both JSON files have been updated with missing articles.")
    time.sleep(60)
# Out:
# Processing article: Rulmeca Acquires Conveying Supplier Douglas Manufacturing
# Processing article: Low-carbon M&A sets a record level of deal activity in 2022 due to increased focus on net-zero goals
# Processing article: Olive Garden Parent Buys Ruths Chris, Plus More Bold Deals
# Processing article: Refuel Acquires 8 C-Stores in 2 Separate Deals
# Processing article: DuPont to Acquire Spectrum Plastics for $1.75B
# Processing article: GMS Acquires Home Lumber & Building Supplies
# Processing article: White & Case advises KAP on sale of flexible films subsection
# Processing article: U.S. private equity firm Advent International and BCI complete acquisition of Maxar Technologies
# Processing article: Where Zimmer Biomet Stands On Future Mergers and Acquisitions
# Processing article: Baxter breaks off biopharma solutions segment in $4.25B private equity deal
# Processing article: Chinese FDI in Europe: 2022 Update
# Processing article: Increase in mergers and acquisitions in first part of 2023
# Processing article: Sanofi Acquires Provention Bio
# Processing article: Maxar Goes Private After Advent International Deal Goes Through
# Processing article: Adobes $20B Figma acquisition falls on UK antitrust radar
# Processing article: JD Sports Fashion Poised to Purchase French Retailer, Groupe Courir
# Processing article: Equiteq completes three deal mandates in Asia Pacific region
# Processing article: CVS Health completes acquisition of Oak Street Health
# Processing article: Boston Scientifics deal to acquire Shockwave Medical reportedly hits a snag
# Processing article: Databricks acquires AI-centric Okera to aid data governance in LLMs
# Processing article: AFC Industries Strikes Again, Acquires New Jerseys Fastbolt
# Processing article: Vodafone merger extremely difficult amid national security fears
# Processing article: Mergers & Acquisitions Seeks Nominations for Best Places to Work in Private Equity
# Processing article: Reverse Mergers  Developments and Considerations for an IPO Alternative
# Processing article: UPDATED: FTC sues to block Amgen's $28B Horizon buy in alarming sign for biopharma M&A
# Processing article: Allkem and Livent plan merger to form major lithium player
# Processing article: Cigna CFO: Expect More Acquisitions Than in Recent Years
# Processing article: Ernst & Young (EY) Acquires ServiceNow Consulting Firm whyaye -
# Processing article: MSP M&A: IT Solutions Consulting Acquires Acropolis Technology Group -
# Processing article: Pfizer, Seagen kick off antitrust review of $43B merger. Will FTC get on board?
# Processing article: Patriot Growth moves for Georgia agency
# Processing article: BP & TravelCenters of America Merger Becomes Official
# Processing article: Estate Tax Planning Considerations for Contemplated M&A Transactions
# Processing article: Henry Schein Reports 1Q Results, 2 Acquisitions
# Processing article: TFI announces two acquisitions to expand LTL business
# Processing article: White & Case Advises Newmont on Its Acquisition of Newcrest
# Processing article: Akin Advises Fluid System Components in Acquisition of Norcan Fluid Power
# Processing article: All the rumors are true: Syneos Health inks $7.1B acquisition with investment firm trio
# Processing article: TravelCenters of America Stockholders OK bp Merger
# Processing article: Blank-Check Pioneer Martin Franklin Launches London IPO
# Processing article: Syneos to be taken private in $7.1B deal
# Processing article: IBM to Help Automate Cloud Data Protection with Acquisition of Polar Security
# Processing article: United Pacific Buys 10 C-Stores From Boyett Petroleum
# Processing article: Tempur Sealy Buys Mattress Firm in $4B Deal
# Processing article: FTC Sues to Block Amgens Acquisition of Horizon Therapeutics
# Processing article: Medtronic and Johnson & Johnson reportedly consider Shockwave acquisition
# Processing article: Gallagher's RPS snaps up MGA
# Processing article: Global M&A Intelligence Report 2023
# Processing article: EY announces the acquisition of consulting services provider whyaye
# Processing article: Labcorp acquires Providence Oregon laboratory assets
# Processing article: Creator economy startup Jellysmack is hiring a new M&A leader as it eyes acquisitions in the 'near future'
# Processing article: Bolt-on acquisition activity continues across industry
# Processing article: MacArthur Co. acquires American Metals Supply
# Processing article: Wearable company Oura acquires digital identification startup Proxy
# Processing article: Avianca Drops Viva Air Merger
# Processing article: Newmont Acquires Newcrest, Creating Worlds Biggest Gold Mining Company
# Processing article: Vitamin Shoppe Parent Company to go Private Following Acquisition by Senior Management
# Processing article: Sak Abrasives Inc. acquires Jowitt & Rodgers in Philadelphia
# Processing article: Amynta Group Completes the Acquisition of Ambridge Group from Brit, a subsidiary of Fairfax
# Processing article: Q1 2023 Beauty Deals Slow to a Trickle. Have We Reached An Inflection Point?
# Processing article: Juno Pharmaceuticals picks up Omega Labs to expand its injectables business in Canada
# Processing article: Lepaya becomes Europes largest EdTech company
# Processing article: UBS and Credit Suisse merge amid global banking concerns
# Processing article: First Solar acquires Swedish perovskite specialist Evolar
# Processing article: Genesis acquires Canadian CRO JSS Medical Research to expand global reach
# Processing article: SPAC Investor Sues Tishman Speyer Over 'Disastrous' Merger
# Processing article: Kaiser Permanente discloses timeline, financial commitments for its VBC megadeal with Geisinger Health
# Processing article: Bluestar Alliance Buys Scotch & Sodas U.S. Business
# Processing article: U.S. Mergers & Acquisitions Monthly Review: April 2023
# Processing article: Hospital coalition urges FTC to abandon unprecedented challenge to state-approved merger
# Processing article: Bill that could doom Fairview-Sanford merger heads to Walzs desk; Fairview, Sanford undeterred
# Processing article: eMudhra Acquires Majority Stake in Ikon Tech Services -
# Processing article: Bank M&A 2023 Deal Tracker: 8 deals announced in April
# Processing article: HCA Healthcare acquiring 41 Texas urgent care centers from FastMed
# Processing article: SoftwareOne Acquires ServiceNow Partner Beniva Consulting Group -
# Processing article: 2023 Mergers and Acquisitions Trends in Asia
# Processing article: Janet Yellen told bank CEOs more mergers may be necessary, sources say
# Processing article: Thermo Fisher eyes up to $50bn M&A in coming years
# Processing article: Kaiser Permanentes acquisition of Geisinger: Billions committed in deal
# Processing article: Bioventus seals up $85M sale of wound care business to LifeNet Health
# Data processing complete. NER training data saved to 'ner_training_data.json'.
# Processed articles with LLM output saved to 'processed_articles.csv'.
# List of all processed articles saved to 'processed_articles.json'.
# Processing complete. Both JSON files have been updated with missing articles.
# Processing article: MSP M&A: NexusTek Buys ICCS & Co -
# Processing article: Divestiture Trends: 2023 Could See More Sell-Offs, but Expect Lengthier and More Extensive Diligence
# Processing article: After talks end with 1 BigLaw firm, Shearman announces plans to merge with another
# Processing article: AIG announces sale of Validus Re
# Processing article: Global Payments execs hint at B2B acquisition
# Processing article: Wicked Kitchen Leads the Way in Plant-Based Industry Transformation with Acquisition of Current Foods
# Processing article: Broadcom, VMware May Push Merger Deadline Past Thanksgiving On $61B Deal
# Processing article: With TA Acquisition, bp Becomes REITs Largest Tenant
# Processing article: Assured Telematics set to merge with Transflo
# Processing article: Global Industrial Acquires Indoff for $69M
# Processing article: Group behind Nexus and Xenia get sold
# Processing article: HEICO to Acquire Wencor for More than $2B
# Processing article: American Metals Supply Acquired by MacArthur Company
# Processing article: Report: ExxonMobil's $100 Million Acquisition Suggests It May Drill for Electric Cars
# Processing article: Mizuho to buy investment bank Greenhill in $550 million takeover
# Processing article: SKC to buy controlling stake in chip test maker ISC for about $300 mn
# Processing article: White & Case advises Autotalks Ltd on sale to Qualcomm Incorporated
# Processing article: Korea's two ride hailing apps to merge in H1, become top operator
# Processing article: Aspirion Announces Acquisition of FIRM Revenue Cycle Management Services, Inc.
# Processing article: U.S. Sues to Block Amgens $27.8 Billion Takeover of Horizon Therapeutics (Published 2023)
# Processing article: Bspoke Group announces first acquisition under new brand
# Processing article: SunCar Completes Merger with Goldenbridge Acquisition
# Processing article: FTC sues to block Amgen acquisition of Horizon Therapeutics
# Processing article: A 32-year-old nears billionaire status by using AI to broker Japan mergers
# Processing article: Nucleus CEO: Ill only do another acquisition if it feels safe
# Processing article: Blend360 Acquires FutureproofAI
# Processing article: MCA Notifies New Rules To Clear Merger & Acquisition Process Within 15-60 Days
# Processing article: MacArthur Co. Acquires American Metals Supply
# Processing article: Timex Group acquires watch retail brand Just Watches
# Processing article: EY announces acquisition of EBS Advisory to further enhance its M&A sustainability and ESG advisory services across Africa.
# Processing article: UK law firm mergers rose last year as growing by acquisition becomes more attractive
# Processing article: MBK Partners puts Koreas largest golf course operator on market
# Processing article: Albertsons starts to assemble merger team, names SpinCo planning head
# Processing article: AlTi Expands Into Singapore With Acquisition
# Processing article: Hospitality tech startups me&u and Mr Yum confirm merger talks are on the menu
# Processing article: Could Core Lithium shares make the merger menu next?
# Processing article: Vet business takeovers raise competition concerns for pet owners
# Processing article: Sony Will Soon Have Over $13 billion To Invest On Merger & Acquisitions
# Processing article: White & Case Advises Tigo Energy, Inc. on the Closing of its Business Combination with Roth CH Acquisition IV Co.
# Processing article: Tough U.S. Financial Conditions Could Torpedo Wall Street Dealmaking, New Research Shows
# Processing article: Minnesota healthcare monopolies law could stop proposed Sanford-Fairview merger
# Processing article: M&A deals require largest outside counsel teams
# Processing article: A Grocery Giant Enjoys the Fruits of a Successful Merger Integration
# Processing article: New mergers, acquisitions in Latin Americas renewable energy market
# Processing article: Ryan Specialty to acquire California-based wholesale broker
# Processing article: Advocate Health reports 0.1% operating margin, $579M net gain for its first post-merger quarter
# Processing article: Siemens teams with hospital giant CommonSpirit to acquire imaging vendor in first of its kind deal
# Processing article: Analysts Skeptical of Choice Hotels Acquisition Interest in Wyndham
# Processing article: Tamarac claims what was unthinkable two years ago -- that it is on the same playing field as iRebal for rebalancing software
# Processing article: Media Localization and Content Providers Merge in Sweden to Form JuneFirst
# Processing article: MSP M&A: ZainTech Acquires Adfolks -
# Processing article: Concentra finds latest acquisition attempt harder to swallow as Atea rejects 'undervalued' offer
# Processing article: The shifting tides of cross-border M&A
# Processing article: Flagstone Foods Acquires Emerald Nuts from Campbell Soup Company
# Processing article: M/C Partners Invests in Communications MSP celito -
# Processing article: Boston Scientific nixes $230M acquisition of stent maker M.I.Tech, citing regulatory roadblocks
# Processing article: White & Case advises Cary Group on expansion in Belgium and Luxembourg
# Processing article: FTD Merges with From You Flowers
# Processing article: Hong Kong SFC Proposes Rule Changes to Remove the Prohibition View Notion in Privatisation Scheme Meeting and Others
# Processing article: Media Localization Provider Visual Data Acquires Frances EVA
# Processing article: Plastiq files for bankruptcy; agrees acquisition deal with Priority
# Processing article: New Investments Refuel Rumors of a RingCentral and 8x8 Merger
# Processing article: Life sciences industry embarks on inorganic digitization through mergers & acquisitions
# Processing article: WeCommerce Holdings Ltd. in connection with its merger with Tiny Capital Ltd. to form Tiny Ltd. | Korea | Global law firm
# Processing article: KeHE to Expand West Coast Distribution Footprint Through Acquisition of DPI
# Processing article: From megaround to $16M buyout: Apexigen limps to exit, accepting Pyxis' bid 300 days after going public
# Processing article: Snowflake acquires Neeva to add generative AI-based search to Data Cloud
# Processing article: Guy Carpenter announces expansion into Israel with Re Solutions acquisition
# Processing article: Tyson Foods Completes Williams Sausage Acquisition
# Processing article: WeCommerce Holdings Ltd. in connection with its merger with Tiny Capital Ltd. to form Tiny Ltd. | Japan | Global law firm
# Processing article: WeCommerce Holdings Ltd. in connection with its merger with Tiny Capital Ltd. to form Tiny Ltd.
# Processing article: Lithium M&A News to Continue in 2023 as Consolidation Ramps Up
# Processing article: Navacord completes largest deal yet
# Processing article: The return of M&A activity in the igaming industry
# Processing article: Dentons advises Giesecke+Devrient on the acquisition of MECOMO
# Processing article: Proposed merger best path forward for DHC, REIT says, but shareholder group disagrees
# Processing article: BluSky Announces Merger with Pennsylvania-Based Mammoth Restoration
# Processing article: Safelite Group Acquires New Angle Glass
# Processing article: Singapores PSA continues to ride M&A wave with Vietnam acquisition
# Processing article: Inmarsat CEO Rajeev Suri to Step Down With Viasat Acquisition
# Data processing complete. NER training data saved to 'ner_training_data.json'.
# Processed articles with LLM output saved to 'processed_articles.csv'.
# List of all processed articles saved to 'processed_articles.json'.
# Processing complete. Both JSON files have been updated with missing articles.
# Processing article: Accenture Wraps Up SAP Solution, Cloud, Sustainability Company Acquisitions
# Processing article: From You Flowers and FTD Announce Merger to Create a New Global Platform in the Floral and Gifting Industry
# Processing article: Daewoo Shipbuilding enters new chapter as Hanwha Ocean
# Processing article: Medtronic acquires insulin patch pump maker EOFlow for $738M amid new MiniMed rollout
# Processing article: To Regulate Big Corporations, Understand How They Got That Way
# Processing article: OCU Group completes acquisition of Northavon Group of companies
# Processing article: Nexus Underwriting, Xenia Broking get sold
# Processing article: ASX mining sector at start of multi-year takeover cycle
# Processing article: Realty Income Corp. Begins Buying Cumberland Farms Properties
# Processing article: Permira Acquiring Majority Stake in Gruppo Florence
# Processing article: Xylem completes acquisition of Evoqua in $7.5B transaction
# Processing article: Infineon strengthens its edge AI offering with Imagimob acquisition
# Processing article: Wall Street deals show unfulfilled ambition of Japans megabanks
# Processing article: inDrive Strengthens B2B Offering through Team Expansion, Tech Acquisition
# Processing article: Asda expected to finalise 10bn merger with EG
# Processing article: Roc360 Further Expands its Leading Portfolio of Brands with Acquisition of Origination Assets of Civic Financial Services
# Processing article: Union Bank, Valleys fourth-largest bank, completes transition after $8B merger
# Processing article: SAP BrandVoice: The Bold Moves That Pay Off For Midsize Distributors Considering Mergers And Acquisitions
# Processing article: Missouri nonprofit health systems BJC HealthCare, Saint Luke's targeting $10B merger
# Processing article: Infinity's merger with MEI in doubt after investors make their own bid
# Processing article: Mergers and acquisitions involving UK companies: January to March 2023
# Processing article: 5 states reviewing healthcare M&A oversight
# Processing article: White & Case advises Norvestor on acquisition of Colmec
# Processing article: Gallagher makes Tennessee acquisition
# Processing article: Healthcare DealmakersCVS closes Oak Street Health deal & more
# Processing article: Infinity merger back on track after MEI turns down 'significantly undervalued' outside offer
# Processing article: White & Case advises Accelleron on acquisition of Officine Meccaniche Torino
# Processing article: BIO: Jazz is auditioning new bandmates in an M&A market ripe with talent
# Processing article: White & Case advises Carlyle on acquisition of Meopta
# Processing article: Erytech accuses investor of trying to 'destabilize' biotech by opposing Pherecydes merger vote
# Processing article: Inszone snaps up another California agency
# Processing article: Amgen extends restraining order in Horizon pursuit as court's scheduling comes into focus
# Processing article: Block Imaging spinning off mobile business after announcing its acquisition by Siemens, CommonSpirit
# Processing article: LIV Golfs Shock PGA Deal Involved Close PIF Adviser Klein (1)
# Processing article: After Stratasys and Desktop Metal announce merger plans, 3D Systems proposes acquisition
# Processing article: Snell & Wilmer Represents Leading Influencer Media Firm Mom Media in Acquisition by Everyday Health Group
# Processing article: TMI Holdings To Merge With Argent Financial Group
# Processing article: Hinton Transportation acquires trailer supply operation
# Processing article: Asset manager consolidation wave continues as two deals announced in 24 hours
# Processing article: AD, The Baron Group Announce Merger
# Processing article: AD to Merge with Groundwater Distribution Buying Group Baron
# Processing article: M&A: Cardinal Healths Outcomes to Merge with Transaction Data Systems
# Processing article: Hightower Continues Growth Streak With $2B RIA Acquisition
# Processing article: Collaborative Agreements in Health Care
# Processing article: Microsoft-Activision Deal Divides Regulators
# Processing article: Amplix Acquires Mobility Solutions Provider Corporate Accessories Group -
# Processing article: Home health bidding wars heat up: Optum makes $3B unsolicited offer for Amedisys
# Processing article: Frontdesk Buys Rival Property Manager Zencity
# Processing article: Rexel to Buy Dutch HVAC Distributor Wasco in $518M Deal
# Processing article: Akin Advises Spire in Acquisition of MoGas and Omega Pipeline Systems
# Processing article: Novo Nordisk offers 154M in negotiations to acquire diabetes devicemaker Biocorp
# Processing article: Altria Completes Acquisition of Njoy
# Processing article: The Biotech Buying Bonanza: Why The FTC's Amgen Battle Won't Chill The Spree
# Processing article: Top 3 mergers and acquisitions in India: Bold moves and brilliant alliances - ET Edge Insights
# Processing article: Shares in Asos Rocket After Report of Approach by Alibaba-backed Turkish Retailer
# Processing article: White & Case advises Riverbed Technology on sale to Vector Capital
# Processing article: Domestic & General boosts overseas expansion with acquisition
# Processing article: Top Trends Shaping Dealmaking in the RIA Space
# Processing article: Getinge offers $290M for single-use bioprocessing equipment maker
# Processing article: Cloud Computing in the UK: Iomart Acquires Extrinsica, a Microsoft Azure Provider
# Processing article: Stran & Company Completes Fourth Acquisition Since Becoming a Publicly Traded Company
# Processing article: Premier Truck Group expands with Canadian acquisition
# Processing article: What is PIF? The Saudi investment fund behind PGA Tour and LIV Golfs merger
# Processing article: Hightower Buys $1 Billion-Asset RIA Boston Hill, Mercer Adds Another PE Backer
# Processing article: Ahead Buys MBX To Boost Edge, Supply Chain, Hyperscale Solutions: Channel M&A
# Processing article: Smart Acquires Managed Account Provider ProManage
# Processing article: Sonepar to Acquire Billows Electric
# Processing article: Magna Completes Acquisition of Veoneer Active Safety Business
# Processing article: Moniepoint is planning to leverage M&A for its next growth stage
# Processing article: Global Partners Completes Deal for 64 Landmark Group C-Stores
# Processing article: 13 healthcare mergers and acquisitions making headlines in May
# Processing article: How to Speed Up IT Systems Integration in a Merger or Acquisition
# Processing article: M&A is a critical tool for growth for Top 100 companies
# Processing article: Council Post: The Top 4 HR Considerations During An Acquisition
# Processing article: Viking M&A Assists with Acquisition of Sencommunications, Inc.
# Processing article: NET Power Completes Merger with Rice Acquisition Corp. II to Accelerate Clean Natural Gas Power Generation
# Processing article: M&A Trends in 2023: What to expect and how to prepare for a successful deal
# Processing article: White & Case Advises Occidental Petroleum on Net Power's US$1.5 Billion Business Combination with Rice Acquisition Corp. II
# Processing article: A look at DTC acquisitions in 2023 so far
# Processing article: Morgan Stanley M&A chief to jump back to big law
# Data processing complete. NER training data saved to 'ner_training_data.json'.
# Processed articles with LLM output saved to 'processed_articles.csv'.
# List of all processed articles saved to 'processed_articles.json'.
# Processing complete. Both JSON files have been updated with missing articles.
# Processing article: Merger enforcers put PE deals under the microscope
# Processing article: Private equity firm acquiring 'leading' teleradiology group that spans 48 states
# Processing article: White & Case advises Mutares on sale of portfolio company SMP
# Processing article: DSG Completes $269M Hisco Acquisition
# Processing article: Pestell Nutrition rebranded as Barentz
# Processing article: CDW Corporation Acquires AWS Partner Enquizit -
# Processing article: Supply Chain M&A: AHEAD Acquires MBX Systems -
# Processing article: Fiserv poised for more M&A
# Processing article: White & Case Advises Prospector Capital Corp. on Business Combination with LeddarTech Inc.
# Processing article: Deal Watch: Wachtell Has Big Week as PGA/LIV Merger Looks ... Shaky
# Processing article: Salvation or 'death warrant'? Erytech's war with activist investor rumbles on as merger vote nears
# Processing article: White & Case advises Morgan Stanley Infrastructure Partners on acquisition of Valoriza Servicios Medioambientales
# Processing article: Batory Foods Acquires Ohio-based Tri-State Companies
# Processing article: Why Becoming a Platform Company is Your Next Best Avenue to Exit
# Processing article: Bayer needs 'midsize acquisition' to reach $10B oncology sales goal, exec says
# Processing article: ANALYSIS: Reps and Warranties Insurance Market: Ever Upward?
# Processing article: Putnam CEO Reynolds Will Remain with Great-West Post Merger
# Processing article: UHY Branches Out in Michigan Via Merger
# Processing article: Nasdaq Inks Its Largest Acquisition Furthering CEO Adena Friedmans Tech Vision
# Processing article: Drexel and Salus Universities Formalize Merger Agreement at Ceremonial Signing
# Processing article: Perspective | The PGA Tour is calling this a victory, but something doesnt smell right
# Processing article: Football M&A: The increasing importance of environmental, social and governance factors
# Processing article: Application Security Posture Management Acquisition: Snyk Buys Enso Security -
# Processing article: Theres More M&A in BlackRocks Future
# Processing article: Acentra Health Emerges as Health Powerhouse Post CNSI-Kepro Merger
# Processing article: Merit Medical spends $132.5M on acquisitions to expand its offerings
# Processing article: Aptean Acquisition of TOTALogistix Enhances its Ability to Help Companies Optimize Logistics
# Processing article: Secrecy, Cigars and a Venetian Wedding: How the PGA Tour Made a Deal with Saudi Arabia (Published 2023)
# Processing article: After SVB: How the Banking Sector Is Impacting M&A
# Processing article: Womack Expands in Midwest with Addition of Morrell Group
# Processing article: TPG Completes Majority Acquisition of Elite
# Processing article: AFC Industries Acquires White Distribution & Supply in Iowa
# Processing article: Confie Expands Portfolio with Two Acquisitions
# Processing article: TPG and AmerisourceBergen Complete Acquisition of OneOncology
# Processing article: AFC Industries Acquires White Distribution and Supply
# Processing article: SPATCO Energy Solutions Acquires MSCS
# Processing article: Womack Machine Supply Adds Morrell Group
# Processing article: Harbour and Talos in merger discussions
# Processing article: York Completes Acquisition of GN&C Developer Emergent Space Technologies
# Processing article: ConnectWise CEO: Were In A Time Horizon To Be Acquired
# Processing article: 'Some will close their gates, others will open to programmatic': Ofer Druker on the future of CTV
# Processing article: Accenture Places $3B AI Bet Following Multiple Acquisitions
# Processing article: Confie expands portfolio with acquisitions of Sanborn's Insurance and Atlantic Insurance Agency
# Processing article: In France, Vivendis Acquisition of Lagardere Approved
# Processing article: Taco Bell Franchisee Adds 39 Stores to Portfolio
# Processing article: Fanatics Acquires Latin American Sports Wholesaler Fexpro
# Processing article: Liberty Mutual Insurance, Generali sign $2.5 billion deal
# Processing article: Top 10 pharma companies have over $120 billion in cash for mergers and acquisitions
# Processing article: How to retain employees after a merger or acquisition
# Processing article: Antitrust Division | Protecting Nascent Competition: Visa and Plaid Abandon Anticompetitive Merger
# Processing article: Healthcare IT Buy: Anatomy IT Acquires IRIS Solutions Solutions -
# Processing article: Alltech, Finnforel Oy acquire Finlands only fish feed factory
# Processing article: Darden Restaurants Completes Acquisition of Ruth's Hospitality Group
# Processing article: Ready to curb tech debt? Start here
# Processing article: Global Transactional Risks review and outlook
# Processing article: Viking M&A assists with acquisition of #1 Yamaha Dealer in the world, Cycle Springs Powersports
# Processing article: Ready for Takeover 2.0?
# Processing article: Investing in Space: Bankers and insiders say M&A action is heating up
# Processing article: L3Harris-Aerojet Merger: A Pro-Competitive Deal with No Antitrust Concerns
# Processing article: Leading Biosimulation Provider Acquires Drug Development Modeling and Simulation Company
# Processing article: ICIG buys again in Germany
# Processing article: Magic Circle Trio Leads on 15B Vodafone-Three Merger
# Processing article: MiddleGround Capital Acquires A.M. Castle & Co.
# Processing article: Hospital system and 2 imaging center chains band together in joint venture deal
# Processing article: Lilly makes fresh bet on IL-17 with $2.4B acquisition of Dice Therapeutics
# Processing article: Sonepar to Merge Irby, Crawford Electric Subsidiaries
# Processing article: Patterson-UTI and NexTier Merge To Create a New Oilfield Services Giant
# Processing article: SPAC deal is among 2023's largest M&A transactions
# Processing article: Darden completes Ruths Chris acquisition
# Processing article: Vodafone, CK Hutchison agree UK mobile business merger
# Processing article: Crawford Electric, Irby Electric to Combine
# Processing article: PNM Resources and Avangrid agree to merger extension
# Processing article: Report: Zepz Seeks M&A Targets After 26% Layoffs
# Processing article: HKEX Reminder - Acquisition of Wealth Management Products is Notifiable Transaction
# Processing article: Mining deal-making declines, but Beaty and others see opportunities
# Processing article: BD sells off surgical instruments unit to Steris for $540M
# Processing article: Premier Inc. carving off non-healthcare group purchasing business in $800M cash deal
# Processing article: Distributor SPATCO Energy Solutions Acquires MSCS
# Processing article: Admiral announces major acquisition
# Processing article: Private equity-backed Capitol Imaging acquires 2 radiology groups spanning 10 locations
# Data processing complete. NER training data saved to 'ner_training_data.json'.
# Processed articles with LLM output saved to 'processed_articles.csv'.
# List of all processed articles saved to 'processed_articles.json'.
# Processing complete. Both JSON files have been updated with missing articles.
# Processing article: Haffner's Grows Store Count With 2 Acquisitions
# Processing article: Large Applebees Franchisee SSCP Finalizes Corner Bakery Acquisition
# Processing article: Nextbite acquired by SBE Hospitality Group CEO Sam Nazarian
# Processing article: Oil, gas deal tracker: Oneok's $18.8B merger in May towers over other deals YTD
# Processing article: Franklin Templetons Yaqub Ahmed Explains the Putnam Acquisition
# Processing article: Telehealth startup Thirty Madison scoops up assets from bankrupt The Pill Club
# Processing article: Centene completes sale of AI business Apixio
# Processing article: Beacon Acquires Silver State Building Materials
# Processing article: OC&C, Strategy&, KPMG and PwC advise on deal in snack world
# Processing article: Vodafone and Three agree merger to form UKs largest mobile operator
# Processing article: Meritus Gas Partners to Acquire Global Calibration Gases
# Processing article: Apple And Disney Merging Into One Mega-Company?
# Processing article: Fast Stop Travel Centers Acquires 3 Triple Stop Locations
# Processing article: Lutronic Partners with Hahn & Co. - Korea's Largest Private Equity Firm with over $27 Billion invested to date
# Processing article: Lexitas Announces Acquisition of Imagine Reporting
# Processing article: NORTHPOINT ROOFING SYSTEMS ANNOUNCES THE ACQUISITION OF CARDINAL ROOFING AND RESTORATION
# Processing article: SKC to sell unit to Glenwood PE at $390 mn for future biz
# Processing article: U.S. Mergers & Acquisitions Monthly Review: May 2023
# Processing article: Firm consolidations can have long lasting impacts on workers labor market outcomes
# Processing article: C&EN looks back at the mergers and sales that made todays chemical giants
# Processing article: Pet food M&A on downturn but deals are picking up
# Processing article: Council Post: How To Know If M&A Is Right For You
# Processing article: Cleantech M&A activity expected to grow, driven by ESG investing and federal funding: West Monroe
# Processing article: A Strategic Vision Inspires a Strategic Acquisition
# Processing article: Deloittes outlook for sports investment in 2023
# Processing article: How the PGA Tours Deal With Saudi Arabias Wealth Fund Could Collapse (Published 2023)
# Processing article: ITOps M&A: Virtana Acquires OpsCruise to Improve Observability -
# Processing article: Netflix Eyes Big Studios as It Ramps Up M&A and A New Evolution (Report)
# Processing article: IBM to buy Apptio for $4.6B to help companies optimize IT spend
# Processing article: Civitas Enters Permian Basin With A Pair Of Acquisitions
# Processing article: Investment Advisory M&A Activity Up 237%, Fidelity Study Shows
# Processing article: Databricks $1.3 billion MosaicML acquisition to boost generative AI offerings
# Processing article: White & Case advises Eni on 4.9 billion acquisition of Neptune Energy
# Processing article: Hospital consolidation followed by inpatient pediatric service closures, study finds
# Processing article: Intelsat and SES Talks End Without a Merger
# Processing article: Akin Advises Thrive Foods in Acquisition of Freeze-Dry Foods
# Processing article: Erytech's merger with Pherecydes reaches the finish line after contentious few months
# Processing article: White & Case advises Norvestor on acquisition of majority stake in Langer & Laumann
# Processing article: Option Care-Amedisys acquisition falls through
# Processing article: Akin Advises Tandym Group in Its Acquisition of AETEA Information Technology
# Processing article: White & Case advises Yamauchi No.10 Family Office on successful campaign to replace Toyo Construction board majority as part of acquisition proposal
# Processing article: Pinstripes plans to go public in Banyan SPAC deal
# Processing article: Conformis stock soars on buyout deal from fellow implant maker restor3d
# Processing article: The Valcourt Group Strengthens Service Portfolio with Acquisition of Clearview Building Services
# Processing article: Attorney General Bonta Joins Landmark FTC Lawsuit Challenging Dangerous Pharmaceutical Merger
# Processing article: Quest Diagnostics Completes Acquisition of Haystack Oncology
# Processing article: Healthcare dealmaking 'resilient' despite regulatory, economic headwinds: PwC
# Processing article: Australia's M&A insurance market enters a new phase
# Processing article: Mergers Labor Effects to Receive Scrutiny Under New Filing Plan (1)
# Processing article: Amedisys Agrees to $3.3 Billion UnitedHealth Merger
# Processing article: H.B. Fuller Completes Two Strategic Acquisitions
# Processing article: JAI Restaurant Group Acquires 20 Taco Bells in Atlanta Market
# Processing article: PIP Acquires U.K. PPE Supplier Ultimate Industrial
# Processing article: Health services M&A holding steady despite economic headwinds
# Processing article: Nasdaqs $10 Billion RegTech Deal Shows Urgency, Cost Of Compliance
# Processing article: Fidelis Insurance Holdings launches IPO
# Processing article: Intelsat walks away from SES merger talks
# Processing article: The Collins Companies Acquires WashburnGarfield Corp.
# Processing article: Warner Bros Discovery Merger Gets Dumber As Layoffs Continue And Company Licenses Streaming Content To... Netflix
# Processing article: Pennsylvania community health system pursuing affiliation with UPMC
# Processing article: Databricks picks up MosaicML, an OpenAI competitor, for $1.3B
# Processing article: GR Marshall joins JMG Group
# Processing article: GCC banks feel consolidation pressure as bidding heats up
# Processing article: Merger Control 2023 | Hong Kong SAR | Global law firm
# Processing article: Spyre, a new biotech spinout, launches via merger with Aeglea
# Processing article: ValueAct Capital Supports Proposed Acquisition of JSR Corp.
# Processing article: 'Open to M&A opportunities that add to HDFC Credila's capabilities'  BPEA EQT's Jimmy Mahtani
# Processing article: Renantis to merge with Ventient Energy, backed by JP Morgan
# Processing article: Deal Diary: Wachtell, Kirkland Work Nasdaq, Adenza Tie-Up
# Processing article: HRSoft Expands Leadership Position in the Compensation Management Market with CompTrak Acquisition
# Processing article: Council Post: Five Hacks For Successful Acquisitions
# Processing article: All The Accenture Acquisitions Of 2023 (So Far)
# Processing article: Guy Carpenter completes acquisition of Israel-based firm
# Processing article: White & Case Advises BYTE Acquisition Corp. on Business Combination with Airship AI Holdings, Inc.
# Processing article: US Xpress votes to approve Knight-Swift acquisition
# Processing article: From IBM to Databricks, Its Been A Big Week For Tech M&A
# Processing article: NFP swoops for two businesses
# Processing article: Employee benefits business launches with backing from Bain Capital Insurance
# Processing article: White & Case advises Regnology on acquisition of Invoke
# Processing article: New HSR Form Will Transform the US Merger Review Process  Publications
# Data processing complete. NER training data saved to 'ner_training_data.json'.
# Processed articles with LLM output saved to 'processed_articles.csv'.
# List of all processed articles saved to 'processed_articles.json'.
# Processing complete. Both JSON files have been updated with missing articles.
# Processing article: Global M&A down sharply in first half: Refinitiv
# Processing article: Antibody aficionado Abcam explores strategic alternativesincluding a potential sale
# Processing article: AI M&A: Source Code Acquires Boston Limited -
# Processing article: Immunome, Morphimmune reverse merge, with ex-Seagen CEO Clay Siegall to lead a year after domestic abuse arrest
# Processing article: Mergers and Acquisitions (M&A) in the Contract Manufacturing Industry - Implications and Outlook - 2023 Edition
# Processing article: The Big Self-Storage REIT Merger: Operator Response to the Union Between Extra Space and Life Storage
# Processing article: 3 recent acquisitions from American Healthcare Systems
# Processing article: UPMC Seeks to Add 2-Hospital Washington Health System
# Processing article: Generational Equity Advises U.S. Uniform & Supply in its Sale to Municipal Emergency Services
# Processing article: Arkema buys S.Korea's PI Advanced for about $800 mn
# Processing article: Intus Bio buys Pattern Genomics to enhance microbiome analysis capabilities
# Processing article: Ardonagh Advisory continues acquisition spree with PB Curran swoop
# Processing article: Three Charged With Illegally Trading Ahead of Trump Media Merger (Published 2023)
# Processing article: India's HDFC Bank completes $40 billion takeover of the country's largest mortgage lender. Heres what it means
# Processing article: Siemens completes acquisition of Mass-Tech Controls Private's EV business for Rs 38 cr
# Processing article: BMS Group swoops for Bluebook
# Processing article: Nassau Financial Group Completes Acquisition of Delaware Life Insurance Company of New York
# Processing article: Ocorian Expands Asia Footprint With Hong Kong Acquisition
# Processing article: BradyIFS Acquires FPC Distribution
# Processing article: Cisco increases its network monitoring capabilities with a couple of acquisitions
# Processing article: Centerbridge Partners and GIC Complete Acquisition of INDUS Realty Trust, Inc.
# Processing article: After merger with Google Maps division, Waze gets hit with layoffs
# Processing article: HDFC-HDFC Bank merger: The story behind success of housing finance behemoth
# Processing article: What Will Amgen Buy Next?
# Processing article: M & A Securities completes RTO, listed as M & A Equity Holdings
# Processing article: M&A deals tumble in first half
# Processing article: Pumps Mergers & Acquisitions Review: Q2 2023
# Processing article: REIT M&A activity picks up in Q2 2023 after 4 all-stock merger deals
# Processing article: Olmix Group acquires Brazilian biotech firm Yes Sinergy
# Processing article: White & Case advises Gerald Champion on acquisition by CHRISTUS Health
# Processing article: How Mergers in the Farm Credit System Have Affected Ag Banks
# Processing article: Amdocs Acquires TEOCO's Service Assurance Business -
# Processing article: ANALYSIS: H1 2023 M&A Activity Was as Bad as It Seemed
# Processing article: Healthcare DealmakersAmedisys agrees to Optum's $3.7B cash offer, UPMC's latest affiliation and more
# Processing article: 11 of the largest M&A healthcare transactions in 1st half of 2023
# Processing article: Generali purchases insurance asset manager Conning Holdings
# Processing article: Viking M&A Assists with Acquisition of Wendel Mechanical
# Processing article: White & Case advises Providence on acquisition of majority stake in d&b
# Processing article: These Are the Biggest Takeaways From the Latest Wealth Management M&A Data
# Processing article: ERP Success Partners Acquires NetSuite ERP Practice From Createch -
# Processing article: BlueAlly Acquires Microsoft Cloud Partner B2B Technologies -
# Processing article: Powersports Listings Mergers & Acquisitions Announces New Ownership at Fun Motors of Longview, Texas
# Processing article: Cross-Border M&A Activity on the Rise
# Processing article: M&A How AI is Reshaping the Due Diligence Process
# Processing article: M&M's maker Mars looks to diversify, announces acquisition of healthy food maker Kevin's Natural Foods
# Processing article: Data Center M&A: DataBank Sells Five Data Centers to Etix Everywhere -
# Processing article: Global Partners Selling 54 Sites in Northeast and Mid-Atlantic
# Processing article: Midsize Banks Face Pressure to Grow Through Acquisition
# Processing article: Report: GTCRs Worldpay Acquisition Is Largest Buyout Financing Since Twitter
# Processing article: Riverside to Expand Salon Concept Bishops Following Acquisition
# Processing article: Dupre Logistics acquires truckload brokerage
# Processing article: White & Case advises Banque des Territoires on investment in JP Energie Environnement
# Processing article: Medtechs dealmaking slump intensifies halfway through 2023
# Processing article: Global Oil and Gas M&A Outlook  Q1 2023
# Processing article: Controversy, Criticism, Profit: PGA and LIV Golf Merger Leaves Many Unanswered Questions
# Processing article: Thermo Fisher fronts over $900M for data intelligence company as M&A strategy takes shape
# Processing article: ResMed acquires sleep and respiratory diagnostics software maker Somnoware
# Processing article: Chicago-area banks get their merger done. It's no small feat in 2023.
# Processing article: 5 biggest mergers & acquisitions in India: Reliance, Tata, Vodafone, Walmart  did their big bets pay off?
# Processing article: Original One PartsTM Merges with Headlights Depot
# Processing article: Vistage makes key acquisition in Malaysia to set the stage for CEO peer advisory expansion in Southeast Asia
# Processing article: RaceTrac to Acquire Gulf Oil
# Processing article: Medtech M&A, VC funding slowed to snail's pace in the first half of 2023: Evaluate
# Processing article: 'It was a rare opportunity'  Manitoba brokerages lift lid on merger
# Processing article: DigitalOcean Acquires Paperspace for $111 Million to Expand AI Offerings
# Processing article: Imperial Dade Acquires 3 Distributors
# Processing article: BorgWarner spins off aftermarket business into PHINIA
# Processing article: Ryan Specialty completes trifecta of acquisitions
# Processing article: Charlie Ergen reportedly looking to merge Dish Network, EchoStar: report
# Processing article: Node4 and Air IT bolster position through acquisitions
# Processing article: Fidelis Insurance Holdings initial public offering closes
# Processing article: 24 Seven Completes Acquisition and Successful Rebranding of Antenna and Creatis, Expanding Footprint in Minnesota and Beyond
# Processing article: Ardonagh Advisory makes acquisition of Sentinel
# Processing article: SKC acquires 45% stake in chip test firm ISC for $400 million
# Processing article: Bosch Acquires Paladin Technologies to Expand North American Building Service Business
# Processing article: Microsofts Activision Blizzard merger cant be blocked by FTC, judge rules
# Processing article: Deal-maker or deal-breaker: the legal ins and outs of using AI in M&A
# Processing article: WM Partners Announces Acquisition of Allergy Research Group
# Processing article: Appcast Acquires Bayard Advertising
# Processing article: Jensten Group snaps up MORE Telemarketing
# Data processing complete. NER training data saved to 'ner_training_data.json'.
# Processed articles with LLM output saved to 'processed_articles.csv'.
# List of all processed articles saved to 'processed_articles.json'.
# Processing complete. Both JSON files have been updated with missing articles.
# Processing article: Alta Convenience Acquires Duran Oils JRs Retail Stores
# Processing article: U.S. Mergers & Acquisitions Monthly Review: June 2023
# Processing article: Inside Bains 2023 Midyear M&A Report
# Processing article: Young space firms are driving acquisition activity
# Processing article: Flowchart showing the splits, mergers, and acquisitions of the former Bell Telephone Company
# Processing article: Hospital M&A deal volume returns to pre-pandemic levels as systems seek out complementary services
# Processing article: FTC asks Pfizer, Seagen for more information on proposed $43B merger
# Processing article: Broker M&A deals steady after slowdown
# Processing article: Open-Source Software and Transactional Due Diligence in Light of Recent Advancements in Technology
# Processing article: Proposed Changes to HSR Notification Form Would Intensify Scrutiny on Private Equity Funds Some Thoughts on What to Expect and How to React
# Processing article: Microsoft Cloud Partner M&A: Evergreen Acquires Western Computer -
# Processing article: White & Case advises Valmet on 380 million acquisition of Korbers Business Area Tissue
# Processing article: MSP M&A: Thrive Acquires IT Freedom -
# Processing article: PE-Backed Novatech Acquires Carolina Business Equipment -
# Processing article: Broker M&A deals fall in first half
# Processing article: Salas O'Brien CEO Looks to Continue 'Merger' Spree
# Processing article: Fintech Laws and Regulations Report 2023-2024 Strategic Cross-Border Mergers & Acquisitions in the Fintech Sector
# Processing article: Rev.io Acquires Professional Services Software Firm Tigerpaw -
# Processing article: Theo Chocolate to Merge with American Licorice Company
# Processing article: Jamf Acquires Apple MDM-as-a-Service Company dataJAR -
# Processing article: Penske Truck Leasing completes Star Truck Rentals, Kris-Way Truck Leasing acquisition
# Processing article: Hungry for more, Lilly tops off weight loss pipeline with $1.9B deal to acquire Versanis
# Processing article: MSP M&A: ScalePad Acquires Adept Managed Continuity -
# Processing article: Proximus Opal Buys Majority Stake in Route Mobile for $721 Million -
# Processing article: Exploring The Signs Of Recovery: A Closer Look at Tech M&A And Revenue Multipliers
# Processing article: M&A: It's not all about the revenue  Gallagher regional leader
# Processing article: Telecom Solutions Acquisition: Upstack Buys Sidepath Global -
# Processing article: Deal Watch: Weil, Wilkinson, Sidley, Skadden Help Microsoft/Activision Merger Push Forward
# Processing article: Too big to specialize? The challenges of mid-sized brokers
# Processing article: M&D has acquired Seidel Diesel Group
# Processing article: M&A deals sink to new lows amid protracted slowdown
# Processing article: PS Logistics acquires Alabama-based Action Dedicated
# Processing article: UCSF Health Plans Purchase of Two Dignity Health Hospitals
# Processing article: South Korean biotech group spies US SPAC as route to Nasdaq
# Processing article: IQVIA sued by feds to block deal that would see it dominate digital pharma ads market
# Processing article: Captrust Acquires $2.3 Billion RIA as M&A Picks up Among Larger Firms
# Processing article: Fairway expands with 3 acquisitions
# Processing article: Franchise Fastlane Acquires Fellow Development Company Raintree
# Processing article: EU OKs Broadcom acquisition of VMware, with strings attached
# Processing article: The Swing buys van-hailing service Tada for $19 mn
# Processing article: Broadcom-VMWare Merger Gets European Regulatory Approval
# Processing article: The Alliance of LIV Golf and the PGA Tour: Heres What to Know (Published 2023)
# Processing article: PLATINUM EQUITY TO ACQUIRE HORTICULTURAL CONTAINER MANUFACTURER HC COMPANIES
# Processing article: Proximus Group to acquire a majority stake in Route Mobile for 643m
# Processing article: Commercial Metals Company Acquires EDSCO Fasteners
# Processing article: DOJ fails to block US Sugars $315M purchase of Imperial Sugar
# Processing article: Electrical Connections Supplier nVent to Acquire TEXA
# Processing article: Signet Has Made Another Acquisition
# Processing article: HonorHealth buys out remaining stake of 26 FastMed urgent cares in Arizona
# Processing article: SANDRIDGE ENERGY, INC. ANNOUNCES THE CLOSING OF AN ACQUISITION WHICH INCREASES ITS INTEREST IN WELLS IT OPERATES IN THE NORTHWEST STACK
# Processing article: Stylitics Buys Fashion-Oriented Visual AI Solution Wide Eyes
# Processing article: RWS Acquires CMS for Legal and Legislative Content for up to USD 47.3M
# Processing article: Mandatory EU financial disclosure increases frequency and quality of M&A deals, says study
# Processing article: High rates extend M&A slump in North America through H1 2023
# Processing article: Draft law on control of mergers and acquisitions presented
# ...
# List of all processed articles saved to 'processed_articles.json'.
# Processing complete. Both JSON files have been updated with missing articles.
# Processing article: Viking M&A Facilitates and Announces Acquisition of Premier Maritime Training School
# Processing article: The AI Gold Rush Is On (Tracking the M&A Mega Trend)
# Processing article: LatAm genomics group goes public in cross-border SPAC merger
# Processing article: ESG is rising as an M&A factor. Just ask U.S. Steel
# Processing article: Home Depot explains plans for SRS Distribution acquisition
# Processing article: Star Bulk Completes Eagle Bulk Acquisition
# Processing article: ZOOZ Power Completes Merger with Keyarch Acquisition
# Processing article: OPINION: Store mergers are becoming a necessity to survive
# Processing article: Crowe Strengthens Texas Presence with Acquisition of Belt Harris Pechacek
# Processing article: FTC wants more info on Boston Scientific, Axonics deal with closing timeline pushed back
# Processing article: Biglaw M&A Is Making A Comeback
# Processing article: Apotex acquires specialty drugmaker Searchlight in expansion move
# Processing article: The biggest AI acquisitions by Apple and other Big Tech firms
# Processing article: Brazil M&A transactions down 4% in Q1
# Processing article: Risant Health Completes Acquisition of Geisinger
# Processing article: Asensus Surgical mulls acquisition offer from Karl Storz
# Processing article: White Cap Expands Rebar Operations with Crimson Steel Supply Acquisition
# Processing article: AlTi Tiedemann Global Continues Acquisitions, Extends US Investment Firepower
# Processing article: Geisinger is now part of Risant Health
# Processing article: Google Parent Alphabet Eyes HubSpot Acquisition: Report
# Processing article: White & Case advises bank syndicate on financing of Tritons acquisition of Siemens Energys Trench business
# Processing article: Shearer Supply Acquires Climatic Comfort Products
# Processing article: Iridium Completes Satelles Acquisition and Introduces Iridium Satellite Time and Location (STL)
# Processing article: Johnson-Lancaster Acquires West Coast Dealership
# Processing article: Canadian deal-making still stuck in a rut, despite the hot markets
# Processing article: Ian Goldberg, Partner, Energy Transactions
# Processing article: White & Case advises EIG and MidOcean Energy on acquisition of LNG interests in Australia
# Processing article: U.S. Mergers & Acquisitions Monthly Review: March 2024
# Processing article: High volume, high value hospital transactions kick off 2024
# Processing article: Are You Ready for the Next Wave of Mergers & Acquisitions?
# Processing article: Long-term care mergers and acquisitions increase year over year
# Processing article: Post mergers and acquisitions, will employees leave or stay? Researchers say 'just ask AI'
# Processing article: gWorks Expands With Acquisition of Freedom Systems
# Processing article: Filtration Mergers & Acquisitions Review: Q1 2024
# Processing article: Italys Prysmian to Buy Encore Wire in $4.2B Deal
# Processing article: CT hospital mergers mean higher prices and fewer competitors, state report says
# Processing article: Why Mergers Might Be the Next Wave of DTC Exits
# Processing article: WilmerHale Advises Eliem Therapeutics in Acquisition of Tenet Medicines and Concurrent $120 Million Private Placement
# Processing article: With largest acquisition to date, Vertex hopes for another blockbuster
# Processing article: Analyzing Healthcare M&A Trends: Q1 2024 Insights
# Processing article: TGI Fridays agrees to merge with 89-unit U.K. franchisee
# Processing article: J&J CEO says M&A strategy 'will continue' after medtech megadeals
# Processing article: Do it Best, United Hardware Merger Approved
# Processing article: Pennsylvania legislators push for UPMC-Washington Health merger approval
# Processing article: South La. company sells for $50 million, what NELA businesses need to know about acquisitions
# Processing article: Pinnacle Mergers & Acquisitions Facilitate the Sale of Honda World of Westminster, California
# Processing article: Wiz Acquires Gem Security to Reinvent SecOps
# Processing article: Resideo to Acquire Snap One in $1.4B Deal
# Processing article: Cyderes Acquires Ipseity Security to Enhance IAM
# Processing article: Special Purpose Acquisition Companies2023 Year End Review and 2024 Outlook
# Processing article: Higginbotham Makes Acquisition of Eagan Insurance in Louisiana
# Processing article: 24 Seven Acquires Filter For Strategic Growth
# Processing article: Samsung Electronics' key M&A man returns; big deals in the offing
# Processing article: Reports: CJ Cheil Jedang to revive sale of feed business
# Processing article: Broadcom's Acquisition Of VMware: A New Dawn For Managed Service Providers
# Processing article: Diamondback Energy kicks off bond sale to fund $26 billion Endeavor acquisition
# Processing article: Sullivans Landscaping & Maintenance completes merger with Shore Property Maintenance
# Processing article: Israels HUB Cyber Security Acquires QPoint
# Processing article: 4me Acquires StatusCast to Enhance IT Service Management Offerings
# Processing article: Aftermarket M&A Environment Shows Promise
# Processing article: Double autoimmune acquisitions as Century, Eliem each pick up peers
# Processing article: ReachOut Technology Acquires Singer Networks
# Processing article: Sila Services LLC Announces Three Acquisitions in Eastern US
# Processing article: Korea's M&A market poised to bounce back after bleak Q1
# Processing article: Peak Rock Capital takes a bite out of Steris with $787M dental business deal
# Processing article: The Best and Worst Media Mergers of the 21st Century
# Processing article: Ropes & Gray Advises Ginkgo Bioworks in Acquisition of AgBiome Microbial Platform Assets
# Processing article: Macy's names 2 independent directors as part of agreement with activist investor
# Processing article: American Industrial Partners Completes Take-Private Acquisition of Boart Longyear
# Processing article: Tapestry Merger With Versace Owner Capri Gets EU, Japan Approval
# Processing article: Accenture Federal Services Inks Deal to Buy Cognosante
# Processing article: Pinnacle Mergers & Acquisitions Facilitate the Sale of Honda World of Westminster, California
# Processing article: Best-In-Class Virology And Oncology: Onconova Therapeutics, Inc. and Trawsfynydd Therapeutics, Inc. Combine to Form Traws Pharma, Inc.
# Processing article: Opinion: Googles rumoured Hubspot acquisition will trigger regulators concerns
# Processing article: Martin Supply Acquires Trinity Hardware Headquarters
# Processing article: FTC Taking Deeper Look At $35B Synopsys-Ansys Merger
# Processing article: 7-Eleven Parent to Shift Focus to Convenience Stores, North American Acquisitions
# Processing article: Building Products & Materials Industry InsightsSpring 2024
# Processing article: Resideo to Acquire Snap One in $1.4B Deal, Boosting ADI Unit
# Processing article: Enauta Moves Forward with 3R Petroleum Merger
# Data processing complete. NER training data saved to 'ner_training_data.json'.
# Processed articles with LLM output saved to 'processed_articles.csv'.
# List of all processed articles saved to 'processed_articles.json'.
# Processing complete. Both JSON files have been updated with missing articles.
# Processing article: Lawyers See Positive Outlook for Mergers & Acquisitions in Australia
# Processing article: Siddharth Jain | Mergers & Acquisitions (M&A) Advisory
# Processing article: Four mega mergers helped increase M&A in Q1
# Processing article: Morris James adds mergers, acquisition practice
# Processing article: TGI Fridays Plans Merger With U.K.-based Franchisee
# Processing article: What's happening in agency M&A in the US and Canada?
# Processing article: Goldman to Add Dealmakers in Paris as Financial M&A Heats Up (1)
# Processing article: Waiting too long can doom a college merger, experts say
# Processing article: Mergers and Acquisitions in 2024: A Cautious Recovery With Strategic Shifts | Daily Business Review
# Processing article: Ten Things to Know About Consolidation in Health Care Provider Markets
# Processing article: White & Case advises Battery Ventures-backed Proemion Holding on acquisition of TrendMiner
# Processing article: Four hurdles for bank buyers to clear
# Processing article: Bruker to acquire NanoString for $392.6M
# Processing article: Q1 2024  Global M&A endures headwinds with pick up in first quarter deal closures
# Processing article: CEI Acquires Fourth Dimension Technologies
# Processing article: Acquisition, New Development Bolster Flynn Group's Applebees Portfolio
# Processing article: Kroger amends proposed Albertsons acquisition
# Processing article: FTC Looks to Block Tapestrys $8.5 Billion Acquisition of Capri Holdings
# Processing article: White & Case advises TotalEnergies on acquisition of remaining 50 percent interest in SapuraOMV
# Processing article: Federal trade commission sues to block $8.5 billion merger of Coach and Michael Kors
# Processing article: TGI Fridays to finally go public through merger with UK franchisee owner
# Processing article: FTC sues to block $8.5B merger that would unite luxury brands Coach and Michael Kors
# Processing article: Rehrig Pacific Acquires Pallet Machinery Manufacturer QTEK Design
# Processing article: Schneider Electric, Bentley Systems Discussing Potential Deal
# Processing article: Custom Truck One Source acquires A&D Maintenance and Repair in New York
# Processing article: Merger & Acquisition Round Up: MidFirst Bank, Provident
# Processing article: DrFirst Acquisition Targets Prior Authorization for Specialty Medications
# Processing article: SEER Group Acquires Two Northwest Contractors
# Processing article: Prysmian to Acquire Encore Wire in $4.2B Deal
# Processing article: Albertsons and Kroger Agree to Sell More Stores to Get Merger Approval
# Processing article: 5 auto carriers propose $180M merger
# Processing article: How to build a global business empire in the 21st century
# Processing article: CoStar to acquire 3D scanning firm Matterport
# Processing article: 7-Eleven Completes Acquisition of 204 Stripes Convenience Stores
# Processing article: Building Materials Distributor TopBuild Calls Off Proposed $960M Acquisition
# Processing article: Value of Irish mergers and acquisitions slips 3% in first quarter
# Processing article: M&A Dealmakers Look to Bite into Pet Food
# Processing article: Valsoft's general counsel, David Felicissimo, on handling complex mergers and acquisitions in-house
# Processing article: Factor Risk Management forms M&A and transactional risks division
# Processing article: FTC sues to block Tapestrys $8.5B acquisition of Capri Holdings
# Processing article: JD Sports announces plan to acquire Hibbett in US expansion
# Processing article: Cobalt Service Partners Announces Acquisitions of Four Security Companies
# Processing article: The evidence grows: Prices spike after mergers between far-flung hospitals
# Processing article: Salesforce Drops $11B Informatica Acquisition Pursuit: Reports
# Processing article: Informatica Co-Founder: The Salesforce Acquisition Is "a Bad Idea"
# Processing article: Report: Flink Raising Money from Investors, Discussing Merger With Rivals
# Processing article: Anti-trust lawsuit filed in push to stop Hawaiian-Alaska airlines merger
# Processing article: FTC sues to block $8.5 billion merger of Coach and Michael Kors owners
# Processing article: Blackstone signs over $1 bn deal with MBK for 1st exit in Korea
# Processing article: Consumers launch lawsuit to block Alaska/Hawaiian merger
# Processing article: F.T.C. Sues to Block $8.5 Billion Fashion Merger
# Processing article: Ballymore Safety Sold to PE Firm One Equity Partners
# Processing article: Large Sonic Operator Adds Zaxbys With Acquisition of Legacy Business
# Processing article: Companies enhancing M&A retention strategies, WTW survey finds
# Processing article: Hedge Funds Weighing Bids for CITGO: Report
# Data processing complete. NER training data saved to 'ner_training_data.json'.
# Processed articles with LLM output saved to 'processed_articles.csv'.
# List of all processed articles saved to 'processed_articles.json'.
# Processing complete. Both JSON files have been updated with missing articles.
# Data processing complete. NER training data saved to 'ner_training_data.json'.
# Processed articles with LLM output saved to 'processed_articles.csv'.
# List of all processed articles saved to 'processed_articles.json'.
# Processing complete. Both JSON files have been updated with missing articles.
# Data processing complete. NER training data saved to 'ner_training_data.json'.
# Processed articles with LLM output saved to 'processed_articles.csv'.
# List of all processed articles saved to 'processed_articles.json'.
# Processing complete. Both JSON files have been updated with missing articles.
# Data processing complete. NER training data saved to 'ner_training_data.json'.
# Processed articles with LLM output saved to 'processed_articles.csv'.
# List of all processed articles saved to 'processed_articles.json'.
# Processing complete. Both JSON files have been updated with missing articles.
# Data processing complete. NER training data saved to 'ner_training_data.json'.
# Processed articles with LLM output saved to 'processed_articles.csv'.
# List of all processed articles saved to 'processed_articles.json'.
# Processing complete. Both JSON files have been updated with missing articles.
# Data processing complete. NER training data saved to 'ner_training_data.json'.
# Processed articles with LLM output saved to 'processed_articles.csv'.
# List of all processed articles saved to 'processed_articles.json'.
# Processing complete. Both JSON files have been updated with missing articles.
# Data processing complete. NER training data saved to 'ner_training_data.json'.
# Processed articles with LLM output saved to 'processed_articles.csv'.
# List of all processed articles saved to 'processed_articles.json'.
# Processing complete. Both JSON files have been updated with missing articles.
# Data processing complete. NER training data saved to 'ner_training_data.json'.
# Processed articles with LLM output saved to 'processed_articles.csv'.
# List of all processed articles saved to 'processed_articles.json'.
# Processing complete. Both JSON files have been updated with missing articles.
# Data processing complete. NER training data saved to 'ner_training_data.json'.
# Processed articles with LLM output saved to 'processed_articles.csv'.
# List of all processed articles saved to 'processed_articles.json'.
# Processing complete. Both JSON files have been updated with missing articles.
# Data processing complete. NER training data saved to 'ner_training_data.json'.
# Processed articles with LLM output saved to 'processed_articles.csv'.
# List of all processed articles saved to 'processed_articles.json'.
# Processing complete. Both JSON files have been updated with missing articles.
# Data processing complete. NER training data saved to 'ner_training_data.json'.
# Processed articles with LLM output saved to 'processed_articles.csv'.
# List of all processed articles saved to 'processed_articles.json'.
# Processing complete. Both JSON files have been updated with missing articles.
# Data processing complete. NER training data saved to 'ner_training_data.json'.
# Processed articles with LLM output saved to 'processed_articles.csv'.
# List of all processed articles saved to 'processed_articles.json'.
# Processing complete. Both JSON files have been updated with missing articles.
# Data processing complete. NER training data saved to 'ner_training_data.json'.
# Processed articles with LLM output saved to 'processed_articles.csv'.
# List of all processed articles saved to 'processed_articles.json'.
# Processing complete. Both JSON files have been updated with missing articles.
# Data processing complete. NER training data saved to 'ner_training_data.json'.
# Processed articles with LLM output saved to 'processed_articles.csv'.
# List of all processed articles saved to 'processed_articles.json'.
# Processing complete. Both JSON files have been updated with missing articles.

# %%
json_file = 'processed_articles.json'

with open(json_file, 'r', encoding='utf-8') as f:
    data = json.load(f)

num_articles = len(data)
print(f"Number of articles processed: {num_articles}")
# Out:
# Number of articles processed: 4759

# %%
json_file = 'ner_training_data.json'

with open(json_file, 'r', encoding='utf-8') as f:
    data = json.load(f)

num_articles = len(data)
print(f"Number of articles processed: {num_articles}")
# Out:
# Number of articles processed: 3976

# %%
# !pip install spacy tqdm scikit-learn
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (3.7.5)
# Requirement already satisfied: tqdm in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (4.66.1)
# Requirement already satisfied: scikit-learn in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (1.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy) (0.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.7.4)
# Requirement already satisfied: jinja2 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy) (1.24.4)
# Requirement already satisfied: colorama in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.6.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (6.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from jinja2->spacy) (2.1.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\umutc\appdata\roaming\python\python310\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.17.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.1/12.8 MB 2.3 MB/s eta 0:00:06
#       --------------------------------------- 0.3/12.8 MB 3.5 MB/s eta 0:00:04
#      - -------------------------------------- 0.5/12.8 MB 4.0 MB/s eta 0:00:04
#      -- ------------------------------------- 0.8/12.8 MB 4.6 MB/s eta 0:00:03
#      --- ------------------------------------ 1.0/12.8 MB 4.5 MB/s eta 0:00:03
#      --- ------------------------------------ 1.1/12.8 MB 4.4 MB/s eta 0:00:03
#      --- ------------------------------------ 1.1/12.8 MB 4.4 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.5/12.8 MB 4.3 MB/s eta 0:00:03
#      ----- ---------------------------------- 1.7/12.8 MB 4.1 MB/s eta 0:00:03
#      ----- ---------------------------------- 1.8/12.8 MB 4.1 MB/s eta 0:00:03
#      ----- ---------------------------------- 1.9/12.8 MB 3.8 MB/s eta 0:00:03
#      ------ --------------------------------- 2.0/12.8 MB 3.7 MB/s eta 0:00:03
#      ------ --------------------------------- 2.0/12.8 MB 3.7 MB/s eta 0:00:03
#      ------ --------------------------------- 2.0/12.8 MB 3.1 MB/s eta 0:00:04
#      ------ --------------------------------- 2.2/12.8 MB 3.3 MB/s eta 0:00:04
#      ------- -------------------------------- 2.3/12.8 MB 3.2 MB/s eta 0:00:04
#      ------- -------------------------------- 2.4/12.8 MB 3.2 MB/s eta 0:00:04
#      ------- -------------------------------- 2.4/12.8 MB 3.2 MB/s eta 0:00:04
#      ------- -------------------------------- 2.4/12.8 MB 2.8 MB/s eta 0:00:04
#      -------- ------------------------------- 2.6/12.8 MB 2.9 MB/s eta 0:00:04
#      -------- ------------------------------- 2.7/12.8 MB 2.9 MB/s eta 0:00:04
#      -------- ------------------------------- 2.8/12.8 MB 2.9 MB/s eta 0:00:04
#      -------- ------------------------------- 2.8/12.8 MB 2.9 MB/s eta 0:00:04
#      -------- ------------------------------- 2.8/12.8 MB 2.8 MB/s eta 0:00:04
#      -------- ------------------------------- 2.9/12.8 MB 2.8 MB/s eta 0:00:04
#      --------- ------------------------------ 2.9/12.8 MB 2.7 MB/s eta 0:00:04
#      --------- ------------------------------ 3.0/12.8 MB 2.7 MB/s eta 0:00:04
#      ---------- ----------------------------- 3.3/12.8 MB 2.7 MB/s eta 0:00:04
#      ---------- ----------------------------- 3.4/12.8 MB 2.7 MB/s eta 0:00:04
#      ----------- ---------------------------- 3.6/12.8 MB 2.8 MB/s eta 0:00:04
#      ----------- ---------------------------- 3.7/12.8 MB 2.8 MB/s eta 0:00:04
#      ----------- ---------------------------- 3.8/12.8 MB 2.7 MB/s eta 0:00:04
#      ------------ --------------------------- 4.0/12.8 MB 2.8 MB/s eta 0:00:04
#      ------------- -------------------------- 4.2/12.8 MB 2.9 MB/s eta 0:00:03
#      ------------- -------------------------- 4.4/12.8 MB 2.9 MB/s eta 0:00:03
#      -------------- ------------------------- 4.7/12.8 MB 3.0 MB/s eta 0:00:03
#      --------------- ------------------------ 4.9/12.8 MB 3.1 MB/s eta 0:00:03
#      --------------- ------------------------ 5.0/12.8 MB 3.1 MB/s eta 0:00:03
#      ---------------- ----------------------- 5.2/12.8 MB 3.1 MB/s eta 0:00:03
#      ---------------- ----------------------- 5.3/12.8 MB 3.1 MB/s eta 0:00:03
#      ----------------- ---------------------- 5.5/12.8 MB 3.1 MB/s eta 0:00:03
#      ----------------- ---------------------- 5.6/12.8 MB 3.1 MB/s eta 0:00:03
#      ----------------- ---------------------- 5.7/12.8 MB 3.1 MB/s eta 0:00:03
#      ------------------ --------------------- 5.9/12.8 MB 3.2 MB/s eta 0:00:03
#      ------------------ --------------------- 5.9/12.8 MB 3.1 MB/s eta 0:00:03
#      ------------------ --------------------- 6.0/12.8 MB 3.1 MB/s eta 0:00:03
#      ------------------- -------------------- 6.2/12.8 MB 3.1 MB/s eta 0:00:03
#      ------------------- -------------------- 6.4/12.8 MB 3.1 MB/s eta 0:00:03
#      -------------------- ------------------- 6.5/12.8 MB 3.1 MB/s eta 0:00:03
#      -------------------- ------------------- 6.6/12.8 MB 3.2 MB/s eta 0:00:02
#      --------------------- ------------------ 6.8/12.8 MB 3.2 MB/s eta 0:00:02
#      --------------------- ------------------ 7.0/12.8 MB 3.2 MB/s eta 0:00:02
#      --------------------- ------------------ 7.0/12.8 MB 3.1 MB/s eta 0:00:02
#      ---------------------- ----------------- 7.2/12.8 MB 3.1 MB/s eta 0:00:02
#      ----------------------- ---------------- 7.4/12.8 MB 3.2 MB/s eta 0:00:02
#      ----------------------- ---------------- 7.6/12.8 MB 3.2 MB/s eta 0:00:02
#      ------------------------ --------------- 7.8/12.8 MB 3.2 MB/s eta 0:00:02
#      ------------------------- -------------- 8.0/12.8 MB 3.3 MB/s eta 0:00:02
#      ------------------------- -------------- 8.2/12.8 MB 3.3 MB/s eta 0:00:02
#      -------------------------- ------------- 8.4/12.8 MB 3.3 MB/s eta 0:00:02
#      -------------------------- ------------- 8.5/12.8 MB 3.3 MB/s eta 0:00:02
#      --------------------------- ------------ 8.7/12.8 MB 3.3 MB/s eta 0:00:02
#      --------------------------- ------------ 8.7/12.8 MB 3.3 MB/s eta 0:00:02
#      --------------------------- ------------ 8.9/12.8 MB 3.3 MB/s eta 0:00:02
#      ---------------------------- ----------- 9.0/12.8 MB 3.3 MB/s eta 0:00:02
#      ---------------------------- ----------- 9.2/12.8 MB 3.3 MB/s eta 0:00:02
#      ----------------------------- ---------- 9.3/12.8 MB 3.3 MB/s eta 0:00:02
#      ----------------------------- ---------- 9.5/12.8 MB 3.3 MB/s eta 0:00:01
#      ------------------------------ --------- 9.7/12.8 MB 3.3 MB/s eta 0:00:01
#      ------------------------------ --------- 9.9/12.8 MB 3.3 MB/s eta 0:00:01
#      ------------------------------- -------- 10.0/12.8 MB 3.3 MB/s eta 0:00:01
#      ------------------------------- -------- 10.1/12.8 MB 3.3 MB/s eta 0:00:01
#      ------------------------------- -------- 10.1/12.8 MB 3.3 MB/s eta 0:00:01
#      ------------------------------- -------- 10.1/12.8 MB 3.3 MB/s eta 0:00:01
#      -------------------------------- ------- 10.3/12.8 MB 3.3 MB/s eta 0:00:01
#      -------------------------------- ------- 10.5/12.8 MB 3.3 MB/s eta 0:00:01
#      --------------------------------- ------ 10.8/12.8 MB 3.3 MB/s eta 0:00:01
#      ---------------------------------- ----- 10.9/12.8 MB 3.3 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.0/12.8 MB 3.3 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.3/12.8 MB 3.4 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.5/12.8 MB 3.4 MB/s eta 0:00:01
#      ------------------------------------ --- 11.6/12.8 MB 3.4 MB/s eta 0:00:01
#      ------------------------------------ --- 11.7/12.8 MB 3.3 MB/s eta 0:00:01
#      ------------------------------------ --- 11.7/12.8 MB 3.3 MB/s eta 0:00:01
#      ------------------------------------ --- 11.7/12.8 MB 3.3 MB/s eta 0:00:01
#      ------------------------------------ --- 11.7/12.8 MB 3.2 MB/s eta 0:00:01
#      ------------------------------------- -- 11.9/12.8 MB 3.2 MB/s eta 0:00:01
#      ------------------------------------- -- 12.0/12.8 MB 3.2 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/12.8 MB 3.2 MB/s eta 0:00:01
#      -------------------------------------- - 12.3/12.8 MB 3.4 MB/s eta 0:00:01
#      -------------------------------------- - 12.4/12.8 MB 3.3 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 3.4 MB/s eta 0:00:01
#      ---------------------------------------  12.8/12.8 MB 3.4 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.7.4)
# Requirement already satisfied: jinja2 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.24.4)
# Requirement already satisfied: language-data>=1.2 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.6.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: colorama in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\umutc\appdata\roaming\python\python310\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.17.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\umutc\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
from spacy.tokens import DocBin

# Load the DocBin objects
train_db = DocBin().from_disk("./train.spacy")
test_db = DocBin().from_disk("./test.spacy")

# Check the number of documents (instances) in each DocBin
num_train_instances = len(train_db)
num_test_instances = len(test_db)

print(f"Number of instances in train_db: {num_train_instances}")
print(f"Number of instances in test_db: {num_test_instances}")
# Out:
# Number of instances in train_db: 3578
# Number of instances in test_db: 398
